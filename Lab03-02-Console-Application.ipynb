// %% [markdown]
// # Lab 3.1 Console Application

// %% [markdown]
// ## 0. Prerequisites

// %% [markdown]
// ก่อนทำการทดลอง ให้ตรวจสอบให้แน่ใจว่าเครื่องคอมพิวเตอร์ได้ติดตั้งซอฟต์แวร์ต่อไปนี้แล้ว
//
// - Visual Studio Code พร้อม
// - extension C# Dev Kit บน Visual Studio Code (ใช้สำหรับการสร้าง project)
// - .NET 8 SDK.

// %% [markdown]
// ## 1. Introduction

// %% [markdown]
// ## 2. Create Application
//
// การทดลองนี้ จะสร้างโปรเจ็กต์ .NET console application ในชื่อ "HelloWorld"
//
// 1. เปิด Visual studio code
// 2. เรียก command palette โดยการกด Ctrl+Shift+P หรือเรียกจากเมนู View->Command Palette...
// 3. ใน command palette พิมพ์ .NET new project แล้วกด enter
//
// ![image.png](attachment:image.png)
//
// 4. รอสักครู่
// 5. พิมพ์ console app แล้วกด enter
//
// ![image-2.png](attachment:image-2.png)
//
//
// 6. ตั้งชื่อโปรเจค  HelloWorld-Lab03  แล้วกด enter
//
// ![image-3.png](attachment:image-3.png)
//
// 7. เลือกที่ตั้ง project (ถ้าไม่ต้องการเปลี่ยนให้กด enter ได้เลย)
//
// ![image-4.png](attachment:image-4.png)
//
// 8. กำหนด option ของ project (ถ้าไม่ต้องการเปลี่ยนให้กด enter ได้เลย)
//
// ![image-5.png](attachment:image-5.png)
//
//
// 9. .net จะสร้าง console application project ตามที่กำหนด โดยจะมีโครงสร้างโฟลเดอร์ดังในรูป
//
// ![image-6.png](attachment:image-6.png)
//
//
// 10. ให้คลิกที่ไฟล์ Program.cs จะเห็นเนื้อหาของโปรแกรมดังรูป
//
// ![image-7.png](attachment:image-7.png)

// %% [markdown]
// ## 3. Run Application
//
//
//
// 11. ถึงตรงนี้จะยังไม่สามารถรันโปรเจคได้ เนื่องจาก vscode ยังไม่มีไฟล์ config สำหรับโปรเจคที่เพิ่งสร้างขึ้น  ให้เรียก  command palette แล้วพิมพ์ generate assest
//
// ![image-2.png](attachment:image-2.png)
//
// dotnet  จะสร้างไฟล์มาให้ ในชื่อ launch.json และ tasks.json ภายใต้โฟลเดอร์  .vscode
//
// ![image-3.png](attachment:image-3.png)
//
// 12. เรียกเมนู Run-> Run Without Debugging
//
//  ![image.png](attachment:image.png)
//
// 13. บันทึกหน้าจอที่ได้

// %% [markdown]
// ![image.png](attachment:image.png)

// %% [markdown]
// ## 4. ทดสอบการแก้ไขปัญหาในการเขียนโปรแกรม

// %% [markdown]
// ### 4.1 การแก้ปัญหาเนื่องจากการใช้ชื่อไม่ถูกต้อง
//
// 14. แก้ code ในบรรทัดที่ 2 ของไฟล์ Program.cs ให้เป็นดังต่อไปนี้
//
// `console.WriteLine("Hello World!");`
//
// 15. รันโปรแกรม และบันทึกว่ามีข้อความ error ว่าอย่างไร (ให้บันทึกเฉพาะข้อความที่แสดง error)

// %% [markdown]
// ![image.png](attachment:image.png)
//
//
// Executing task: C:\Program Files\dotnet\dotnet.exe build C:\Users\Wipat\CL2567\CL67-01\github-demo\66030281\HelloWorld-Lab03/HelloWorld-Lab03.sln /property:GenerateFullPaths=true /consoleloggerparameters:NoSummary;ForceNoAlign
//
// MSBuild version 17.9.4+90725d08d for .NET
//   Determining projects to restore...
//   All projects are up-to-date for restore.
// C:\Users\Wipat\CL2567\CL67-01\github-demo\66030281\HelloWorld-Lab03\HelloWorld-Lab03\Program.cs(1,1): error CS0103: The name 'console' does not exist in the current context [C:\Users\Wipat\CL2567\CL67-01\github-demo\66030281\HelloWorld-Lab03\HelloWorld-Lab03\HelloWorld-Lab03.csproj]
//
//  *  The terminal process "C:\Program Files\dotnet\dotnet.exe 'build', 'C:\Users\Wipat\CL2567\CL67-01\github-demo\66030281\HelloWorld-Lab03/HelloWorld-Lab03.sln', '/property:GenerateFullPaths=true', '/consoleloggerparameters:NoSummary;ForceNoAlign'" terminated with exit code: 1.
//  *  Terminal will be reused by tasks, press any key to close it.

// %% [markdown]
// ### 4.2 การแก้ปัญหาเนื่องจากการใช้ชื่อไม่ถูกต้อง
//
// 16. แก้ code ในบรรทัดที่ 2 ของไฟล์ Program.cs ให้เป็นดังต่อไปนี้
//
// `Console.WriteLine('Hello World!');`
//
// 17. รันโปรแกรม และบันทึกว่ามีข้อความ error ว่าอย่างไร (ให้บันทึกเฉพาะข้อความที่แสดง error)

// %% [markdown]
// ข้อ 17
//
// ![image.png](attachment:image.png)
//  *  Executing task: C:\Program Files\dotnet\dotnet.exe build C:\Users\Wipat\CL2567\CL67-01\github-demo\66030281\HelloWorld-Lab03/HelloWorld-Lab03.sln /property:GenerateFullPaths=true /consoleloggerparameters:NoSummary;ForceNoAlign
//
// MSBuild version 17.9.4+90725d08d for .NET
//   Determining projects to restore...
//   All projects are up-to-date for restore.
// C:\Users\Wipat\CL2567\CL67-01\github-demo\66030281\HelloWorld-Lab03\HelloWorld-Lab03\Program.cs(1,1): error CS0103: The name 'console' does not exist in the current context [C:\Users\Wipat\CL2567\CL67-01\github-demo\66030281\HelloWorld-Lab03\HelloWorld-Lab03\HelloWorld-Lab03.csproj]
//
//  *  The terminal process "C:\Program Files\dotnet\dotnet.exe 'build', 'C:\Users\Wipat\CL2567\CL67-01\github-demo\66030281\HelloWorld-Lab03/HelloWorld-Lab03.sln', '/property:GenerateFullPaths=true', '/consoleloggerparameters:NoSummary;ForceNoAlign'" terminated with exit code: 1.
//  *  Terminal will be reused by tasks, press any key to close it.
//
//  *  Executing task: C:\Program Files\dotnet\dotnet.exe build C:\Users\Wipat\CL2567\CL67-01\github-demo\66030281\HelloWorld-Lab03/HelloWorld-Lab03.sln /property:GenerateFullPaths=true /consoleloggerparameters:NoSummary;ForceNoAlign
//
// MSBuild version 17.9.4+90725d08d for .NET
//   Determining projects to restore...
//   All projects are up-to-date for restore.
//   HelloWorld-Lab03 -> C:\Users\Wipat\CL2567\CL67-01\github-demo\66030281\HelloWorld-Lab03\HelloWorld-Lab03\bin\Debug\net8.0\HelloWorld-Lab03.dll
//  *  Terminal will be reused by tasks, press any key to close it.
//
//  *  Executing task: C:\Program Files\dotnet\dotnet.exe build C:\Users\Wipat\CL2567\CL67-01\github-demo\66030281\HelloWorld-Lab03/HelloWorld-Lab03.sln /property:GenerateFullPaths=true /consoleloggerparameters:NoSummary;ForceNoAlign
//
// MSBuild version 17.9.4+90725d08d for .NET
//   Determining projects to restore...
//   All projects are up-to-date for restore.
// C:\Users\Wipat\CL2567\CL67-01\github-demo\66030281\HelloWorld-Lab03\HelloWorld-Lab03\Program.cs(2,1): error CS1056: Unexpected character '`' [C:\Users\Wipat\CL2567\CL67-01\github-demo\66030281\HelloWorld-Lab03\HelloWorld-Lab03\HelloWorld-Lab03.csproj]
// C:\Users\Wipat\CL2567\CL67-01\github-demo\66030281\HelloWorld-Lab03\HelloWorld-Lab03\Program.cs(2,20): error CS1012: Too many characters in character literal [C:\Users\Wipat\CL2567\CL67-01\github-demo\66030281\HelloWorld-Lab03\HelloWorld-Lab03\HelloWorld-Lab03.csproj]
// C:\Users\Wipat\CL2567\CL67-01\github-demo\66030281\HelloWorld-Lab03\HelloWorld-Lab03\Program.cs(2,36): error CS1056: Unexpected character '`' [C:\Users\Wipat\CL2567\CL67-01\github-demo\66030281\HelloWorld-Lab03\HelloWorld-Lab03\HelloWorld-Lab03.csproj]
//
//  *  The terminal process "C:\Program Files\dotnet\dotnet.exe 'build', 'C:\Users\Wipat\CL2567\CL67-01\github-demo\66030281\HelloWorld-Lab03/HelloWorld-Lab03.sln', '/property:GenerateFullPaths=true', '/consoleloggerparameters:NoSummary;ForceNoAlign'" terminated with exit code: 1.
//  *  Terminal will be reused by tasks, press any key to close it.
//
//  *  Executing task: C:\Program Files\dotnet\dotnet.exe build C:\Users\Wipat\CL2567\CL67-01\github-demo\66030281\HelloWorld-Lab03/HelloWorld-Lab03.sln /property:GenerateFullPaths=true /consoleloggerparameters:NoSummary;ForceNoAlign
//
// MSBuild version 17.9.4+90725d08d for .NET
//   Determining projects to restore...
//   All projects are up-to-date for restore.
// C:\Users\Wipat\CL2567\CL67-01\github-demo\66030281\HelloWorld-Lab03\HelloWorld-Lab03\Program.cs(2,1): error CS1056: Unexpected character '`' [C:\Users\Wipat\CL2567\CL67-01\github-demo\66030281\HelloWorld-Lab03\HelloWorld-Lab03\HelloWorld-Lab03.csproj]
// C:\Users\Wipat\CL2567\CL67-01\github-demo\66030281\HelloWorld-Lab03\HelloWorld-Lab03\Program.cs(2,20): error CS1012: Too many characters in character literal [C:\Users\Wipat\CL2567\CL67-01\github-demo\66030281\HelloWorld-Lab03\HelloWorld-Lab03\HelloWorld-Lab03.csproj]
// C:\Users\Wipat\CL2567\CL67-01\github-demo\66030281\HelloWorld-Lab03\HelloWorld-Lab03\Program.cs(2,36): error CS1056: Unexpected character '`' [C:\Users\Wipat\CL2567\CL67-01\github-demo\66030281\HelloWorld-Lab03\HelloWorld-Lab03\HelloWorld-Lab03.csproj]
//
//  *  The terminal process "C:\Program Files\dotnet\dotnet.exe 'build', 'C:\Users\Wipat\CL2567\CL67-01\github-demo\66030281\HelloWorld-Lab03/HelloWorld-Lab03.sln', '/property:GenerateFullPaths=true', '/consoleloggerparameters:NoSummary;ForceNoAlign'" terminated with exit code: 1.
//  *  Terminal will be reused by tasks, press any key to close it.
//
//  *  Executing task: dotnet: build C:\Users\Wipat\CL2567\CL67-01\github-demo\66030281\HelloWorld-Lab03\HelloWorld-Lab03\HelloWorld-Lab03.csproj
//
// dotnet build C:\Users\Wipat\CL2567\CL67-01\github-demo\66030281\HelloWorld-Lab03\HelloWorld-Lab03\HelloWorld-Lab03.csproj /property:GenerateFullPaths=true /consoleloggerparameters:NoSummary /p:Configuration=Debug /p:Platform="AnyCPU"
// MSBuild version 17.9.4+90725d08d for .NET
//   Determining projects to restore...
//   All projects are up-to-date for restore.
// C:\Users\Wipat\CL2567\CL67-01\github-demo\66030281\HelloWorld-Lab03\HelloWorld-Lab03\Program.cs(2,1): error CS1056: Unexpected character '`' [C:\Users\Wipat\CL2567\CL67-01\github-demo\66030281\HelloWorld-Lab03\HelloWorld-Lab03\HelloWorld-Lab03.csproj]
// C:\Users\Wipat\CL2567\CL67-01\github-demo\66030281\HelloWorld-Lab03\HelloWorld-Lab03\Program.cs(2,20): error CS1012: Too many characters in character literal [C:\Users\Wipat\CL2567\CL67-01\github-demo\66030281\HelloWorld-Lab03\HelloWorld-Lab03\HelloWorld-Lab03.csproj]
// C:\Users\Wipat\CL2567\CL67-01\github-demo\66030281\HelloWorld-Lab03\HelloWorld-Lab03\Program.cs(2,36): error CS1056: Unexpected character '`' [C:\Users\Wipat\CL2567\CL67-01\github-demo\66030281\HelloWorld-Lab03\HelloWorld-Lab03\HelloWorld-Lab03.csproj]
//
//  *  The terminal process terminated with exit code: 1.
//  *  Terminal will be reused by tasks, press any key to close it.
//
//  *  Executing task: C:\Program Files\dotnet\dotnet.exe build C:\Users\Wipat\CL2567\CL67-01\github-demo\66030281\HelloWorld-Lab03/HelloWorld-Lab03.sln /property:GenerateFullPaths=true /consoleloggerparameters:NoSummary;ForceNoAlign
//
// MSBuild version 17.9.4+90725d08d for .NET
//   Determining projects to restore...
//   All projects are up-to-date for restore.
// C:\Users\Wipat\CL2567\CL67-01\github-demo\66030281\HelloWorld-Lab03\HelloWorld-Lab03\Program.cs(2,1): error CS1056: Unexpected character '`' [C:\Users\Wipat\CL2567\CL67-01\github-demo\66030281\HelloWorld-Lab03\HelloWorld-Lab03\HelloWorld-Lab03.csproj]
// C:\Users\Wipat\CL2567\CL67-01\github-demo\66030281\HelloWorld-Lab03\HelloWorld-Lab03\Program.cs(2,20): error CS1012: Too many characters in character literal [C:\Users\Wipat\CL2567\CL67-01\github-demo\66030281\HelloWorld-Lab03\HelloWorld-Lab03\HelloWorld-Lab03.csproj]
// C:\Users\Wipat\CL2567\CL67-01\github-demo\66030281\HelloWorld-Lab03\HelloWorld-Lab03\Program.cs(2,36): error CS1056: Unexpected character '`' [C:\Users\Wipat\CL2567\CL67-01\github-demo\66030281\HelloWorld-Lab03\HelloWorld-Lab03\HelloWorld-Lab03.csproj]
//
//  *  The terminal process "C:\Program Files\dotnet\dotnet.exe 'build', 'C:\Users\Wipat\CL2567\CL67-01\github-demo\66030281\HelloWorld-Lab03/HelloWorld-Lab03.sln', '/property:GenerateFullPaths=true', '/consoleloggerparameters:NoSummary;ForceNoAlign'" terminated with exit code: 1.
//  *  Terminal will be reused by tasks, press any key to close it.
//
//  *  Executing task: C:\Program Files\dotnet\dotnet.exe build C:\Users\Wipat\CL2567\CL67-01\github-demo\66030281\HelloWorld-Lab03/HelloWorld-Lab03.sln /property:GenerateFullPaths=true /consoleloggerparameters:NoSummary;ForceNoAlign
//
// MSBuild version 17.9.4+90725d08d for .NET
//   Determining projects to restore...
//   All projects are up-to-date for restore.
// C:\Users\Wipat\CL2567\CL67-01\github-demo\66030281\HelloWorld-Lab03\HelloWorld-Lab03\Program.cs(2,1): error CS1056: Unexpected character '`' [C:\Users\Wipat\CL2567\CL67-01\github-demo\66030281\HelloWorld-Lab03\HelloWorld-Lab03\HelloWorld-Lab03.csproj]
// C:\Users\Wipat\CL2567\CL67-01\github-demo\66030281\HelloWorld-Lab03\HelloWorld-Lab03\Program.cs(2,20): error CS1012: Too many characters in character literal [C:\Users\Wipat\CL2567\CL67-01\github-demo\66030281\HelloWorld-Lab03\HelloWorld-Lab03\HelloWorld-Lab03.csproj]
// C:\Users\Wipat\CL2567\CL67-01\github-demo\66030281\HelloWorld-Lab03\HelloWorld-Lab03\Program.cs(2,36): error CS1056: Unexpected character '`' [C:\Users\Wipat\CL2567\CL67-01\github-demo\66030281\HelloWorld-Lab03\HelloWorld-Lab03\HelloWorld-Lab03.csproj]
//
//  *  The terminal process "C:\Program Files\dotnet\dotnet.exe 'build', 'C:\Users\Wipat\CL2567\CL67-01\github-demo\66030281\HelloWorld-Lab03/HelloWorld-Lab03.sln', '/property:GenerateFullPaths=true', '/consoleloggerparameters:NoSummary;ForceNoAlign'" terminated with exit code: 1.
//  *  Terminal will be reused by tasks, press any key to close it.
