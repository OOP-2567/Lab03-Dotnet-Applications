// %% [markdown]
// # Lab 3.2 Windows form Application

// %% [markdown]
// ## 0. Prerequisites
//
// ก่อนทำการทดลอง ให้ตรวจสอบให้แน่ใจว่าเครื่องคอมพิวเตอร์ได้ติดตั้งซอฟต์แวร์ต่อไปนี้แล้ว
//
// - Visual Studio Code
// - ติดตั้ง extension C# Dev Kit บน Visual Studio Code (ใช้สำหรับการสร้าง project)
// - .NET 8 SDK.

// %% [markdown]
// ## 1. Introduction
//
// Windows form Application เป็นเทคโนโลยีที่ใช้มายาวนาน (อาจจะมากกว่า 20 ปี) จึงมี library ด้านกราฟฟิกส์ที่ยึดโยงกับ win32 เป็นอย่างมาก
//
// กรณีดังกล่าวจึงเป็นเหตุผลหนึ่งที่ทำให้มีความยากในการออกแบบ windows form บน editor อื่นๆ ที่ไม่ใช่ Visual Studio
//
// เพื่อไม่ให้นักศึกษาต้องเรียนรู้การใช้งานเครื่องมือพัฒนาที่หลากหลานและเกินจำเป็น การทดลองในวิชานี้ จะมีขอบเขตอยู่ใน Visual Studio Code เป็นหลัก
//
// สำหรับผู้ที่ต้องการสร้าง windows form application ที่ใช้งานจริง ต้องไปเรียนรู้การใช้ visual studio ซึงก็ไม่ยากในการทำความเข้าใจ
//
// https://learn.microsoft.com/en-us/dotnet/desktop/winforms/?view=netdesktop-8.0

// %% [markdown]
// ## 2. Create Application
//
// 1. เปิด visual studio code
//
// __หมายเหตุ__
//    เนื่องจากไม่มีตัวเลือกในการสร้าง .net project จากเมนู View->Command Palette... จึงต้องใช้ terminal ในการสร้างและทดสอบโปรเจค
//
// 2. เปิด terminal โดยใช้เมนู view->terminal หรือกด Ctrl + Shift + `
//
//    2.1 ตรวจสอบว่าเป็น folder ที่จะสร้าง project ไว้ในนั้นจริง ๆ
//
// 3. พิมพ์ `dotnet new winforms -n HelloForm1 -o HelloForm1` ใน terminal
// 4. พิมพ์คำสั่ง `dir` ใน terminal เพื่อดูว่ามี folder ชื่อ HelloForm1 ที่ถูกสร้างขึ้นใหม่อยู่แล้วหรือยัง ถ้ายังไม่มี อาจจะเกิดจากการสร้างไม่สมบูรณ์
// 5. พิมพ์คำสั่ง `cd HelloForm1` เพื่อเปลี่ยน folder  ที่ทำงานไปอยู่ในโปรเจค HelloForm1

// %% [markdown]
// ## 3. Build Application
//
// 6. พิมพ์คำสั่ง `dotnet build`  ใน terminal เพื่อ build โปรแกรม

// %% [markdown]
// ## 4. Run Application
// 7. พิมพ์คำสั่ง `dotnet run` ใน terminal เพื่อรันโปรแกรม

// %% [markdown]
// ## 5. เพิ่ม Button Control ให้กับ Windows form

// %% [markdown]
// 8. อ่าน document ในส่วนของ Definition และ Examples ของคลาส Button จาก [dotnet/api/system.windows.forms.button](https://learn.microsoft.com/en-us/dotnet/api/system.windows.forms.button?view=windowsdesktop-9.0)
// 9. เพิ่ม code ต่อไปนี้ในเมธอด ___private void InitializeComponent()___ ซึ่งอยู่ในไฟล์ __Form1.Designer.cs__
//
// ```cs
//     Button button1 = new Button();
//     Controls.Add(button1);
// ```
//
// ตามตัวอย่างในรูป
//
//
// ![image.png](attachment:image.png)
//
// 10. พิมพ์คำสั่ง `dotnet run` ใน terminal เพื่อรันโปรแกรม

// %% [markdown]
// จากการรันโปรแกรม จะได้ปุ่มกดที่ว่างเปล่ามา 1 ปุ่ม ให้เพิ่ม lebel สำหรับปุ่ม โดยใช้ property ที่ชื่อ Text ให้ปรากฏบนปุ่ม

// %% [markdown]
// 11. ปรับเปลี่ยน code ในข้อ 9 ให้เป็นดังนี้
//
// >   ```csharp
// >   Button button1 = new Button();
// >   button1.Text = "button 1";
// >   Controls.Add(button1);
// >   ```
//
// 12. พิมพ์คำสั่ง `dotnet run` ใน terminal เพื่อรันโปรแกรม

// %% [markdown]
// ## 6. ทดลองสร้างโปรแกรมบวกเลขสองจำนวน

// %% [markdown]
// 13. สร้างโปรเจค windows form ใหม่ ให้ชื่อว่า FormAdd
//
//     13.1 ใน terminal ถ้ายังอยู่ใน folder ของโปรเจค HelloForm1 พิมพ์คำสั่ง `cd ..` เพื่อย้ายโฟลเดอร์ที่ทำงานออกมาจาก  HelloForm1
//
//     13.2 ใน terminal พิมพ์ `dotnet new winforms -n FormAdd -o FormAdd`
//
//     13.3 ใน terminal ย้ายเข้าไปทำงานในโฟลเดอร์  FormAdd โดยพิมพ์คำสั่ง `cd FormAdd`
//
// 14. ทดลองรันโปรแกรม โดยสั่ง  `dotnet run`

// %% [markdown]
// 15 วางเป้าหมายสำหรับโปรแกรมที่จะสร้าง
//
// ![image.png](attachment:image.png)
//
// โปรแกรมที่จะสร้าง ประกอบด้วยช่องข้อความสำหรับใส่ตัวเลข 2 ตัว เป็นตัวตั้งและตัวบวกตามลดับ
//
// ถัดลงมาเป็นปุ่มกดสำหรับการบวกเลชสองจำนวนเข้าด้วยกัน
//
// ด้านล่างสุด เป็นช่องข้อความที่ใส่ผลลัพธ์ที่ได้จากการบวก
//
// ด้านซ้ายของช่องข้อความจะมีชื่อตัวแปรกำกับไว้ทั้งสามตัว

// %% [markdown]
// 16.1 เพิ่ม code สำหรับการแสดงผลบน windows form โดยจะเพิ่มต่อเนื่องลงไปด้านล่างตามลำดับ
//
// ให้เพิ่ม code สำหรับการสร้าง object ที่จะวางบน windows form  ไว้ถัดลงมาจากบรรทัด   `this.Text = "Form1";`
//
//
// ![image.png](attachment:image.png)
//
//  Code ที่ต้องเพิ่ม
//
//
// >    ```cs
// >    // สร้าง object ของ controls ที่จะวางบน form
// >    buttonAdd = new Button();
// >    label_A = new Label();
// >    label_B= new Label();
// >    label_C= new Label();
// >    textBox_A = new TextBox();
// >    textBox_B = new TextBox();
// >    textBox_C = new TextBox();
// >
// >    // หยุดการแสดงผลบน form ชั่วคราว (freeze) โดยคำสั่ง SuspendLayout();
// >    // เพื่อไม่ให้เกิดการกระพริบในระหว่างที่เพิ่ม control ทีละตัว
// >    // กรณีดังกล่าวอาจจะเกิดขึ้นได้ในตอนที่คอมพิวเตอร์ทำงานหนัก หรือการ์ดแสดงผลทำงานช้า
// >    // ซึ่งจะทำให้เกิดความไม่สบายตาแก่ผู้ใช้
// >    // controls ต่างๆ ที่ถูกเพิ่มหลังคำสั่ง SuspendLayout(); จะไม่ถูกนำไปแสดงผลบนหน้าจอ
// >    // ต้องใช้คำสั่ง ResumeLayout เพื่อยกเลิกการ freez หน้าจอ
// >    SuspendLayout();
// >
// >    // เพิ่ม label สำหรับตัวแปร A
// >    label_A.AutoSize = true;
// >    label_A.Location = new Point(25, 24);
// >    label_A.Name = "label_A";
// >    label_A.Size = new Size(15, 15);
// >    label_A.Text = "A";
// >    Controls.Add(label_A);
// >
// >
// >    // เมื่อเพิ่ม controls เสร็จแล้ว ให้เรียก ResumeLayout(false); เพื่อ update หน้าจอชอง form
// >    // จะทำให้โปรแกรมสามารถรันได้ตามปกติ
// >    ResumeLayout(false);
// >    PerformLayout();
// >    ```
//
// 16.2 เพิ่มตัวแปร reference ของตัวแปรบน  windows form ไว้ก่อนบรรทัด #endregion
//
// __หมายเหตุ__
// นอกจากการสร้าง object ในเมธอด private void InitializeComponent() แล้ว
// เราจำเป็นต้องเพิ่มตัวแปร reference ของ controls ไว้ในฐานะสมาชิกของคลาส Form1 ด้วย
// มิฉะนั้นจะไม่สามารถเรียกใช้จากส่วนอื่นของคลาสได้
//
// >    ```cs
// >    Button buttonAdd;
// >    Label label_A;
// >    Label label_B;
// >    Label label_C;
// >    TextBox textBox_A;
// >    TextBox textBox_B;
// >    TextBox textBox_C;
// >    ```
//
// 17. รันโปรแกรม โดยพิมพ์  `dotnet run` ใน terminal
// 18. สังเกตุและบันทึกผล

// %% [markdown]
// ![Screenshot 2024-12-20 150108.png](<attachment:Screenshot 2024-12-20 150108.png>)

// %% [markdown]
// #### 19. เพิ่ม control ต่าง ๆ โดยเพิ่มถัดจากบรรทัด  __Controls.Add(label_A);__
//
// 19.1 เพิ่ม Label_B
//
// >    ```cs
// >    label_B.AutoSize = true;
// >    label_B.Location = new Point(26, 53);
// >    label_B.Name = "label_B";
// >    label_B.Size = new Size(14, 15);
// >    label_B.Text = "B";
// >    Controls.Add(label_B);
// >    ```
//
// __หมายเหตุ__
//
// การเพิ่ม Controls ต่าง ๆ  ไว้หลังจากบรรทัด ResumeLayout(false);  ก็ยังคงแสดงผลได้เช่นกัน แต่อาจจะเกิดการ update หน้าจอของโปรแกรมที่กระพริบได้
//
// 19.2 รันโปรแกรม โดยพิมพ์  `dotnet run` ใน terminal
//
// 19.3 สังเกตุและบันทึกผล

// %% [markdown]
// ![Screenshot 2024-12-20 150228.png](<attachment:Screenshot 2024-12-20 150228.png>)

// %% [markdown]
// Screenshot 2024-12-20 150228.png](<attachment:Screenshot 2024-12-20 150228.png>)

// %% [markdown]
// #### 20. เพิ่ม Label_B
//
// 20.1 Code ทื่ต้องเพิ่ม
//
// >    ```cs
// >    label_C.AutoSize = true;
// >    label_C.Location = new Point(26, 112);
// >    label_C.Name = "label_C";
// >    label_C.Size = new Size(15, 15);
// >    label_C.Text = "C";
// >    Controls.Add(label_C);
// >    ```
//
// 20.2 รันโปรแกรม โดยพิมพ์  `dotnet run` ใน terminal
//
// 20.3 สังเกตุและบันทึกผล

// %% [markdown]
// ![Screenshot 2024-12-20 150346.png](<attachment:Screenshot 2024-12-20 150346.png>)

// %% [markdown]
// #### 21. เพิ่ม textBox_A
//
// 21.1 Code ทื่ต้องเพิ่ม
//
// >    ```cs
// >    textBox_A.Location = new Point(46, 20);
// >    textBox_A.Name = "textBox_A";
// >    textBox_A.Size = new Size(100, 23);
// >    Controls.Add(textBox_A);
// >    ```
//
// 21.2 รันโปรแกรม โดยพิมพ์  `dotnet run` ใน terminal
//
// 21.3 สังเกตุและบันทึกผล

// %% [markdown]
// ![Screenshot 2024-12-20 150425.png](<attachment:Screenshot 2024-12-20 150425.png>)

// %% [markdown]
// #### 22. เพิ่ม textBox_B
//
// 22.1 Code ทื่ต้องเพิ่ม
//
// >    ```cs
// >    textBox_B.Location = new Point(46, 49);
// >    textBox_B.Name = "textBox_B";
// >    textBox_B.Size = new Size(100, 23);
// >    Controls.Add(textBox_B);
// >    ```
//
// 22.2 รันโปรแกรม โดยพิมพ์  `dotnet run` ใน terminal
//
// 22.3 สังเกตุและบันทึกผล

// %% [markdown]
// ![Screenshot 2024-12-20 150515.png](<attachment:Screenshot 2024-12-20 150515.png>)

// %% [markdown]
// #### 23. เพิ่ม textBox_C

// %% [markdown]
// 23.1 Code ทื่ต้องเพิ่ม
//
// >    ```cs
// >    textBox_C.Location = new Point(46, 108);
// >    textBox_C.Name = "textBox_C";
// >    textBox_C.Size = new Size(100, 23);
// >    Controls.Add(textBox_C);
// >    ```
// 23.2 รันโปรแกรม โดยพิมพ์  `dotnet run` ใน terminal
//
// 23.3 สังเกตุและบันทึกผล

// %% [markdown]
// ![Screenshot 2024-12-20 150550.png](<attachment:Screenshot 2024-12-20 150550.png>)

// %% [markdown]
// #### 24. เพิ่ม buttonAdd

// %% [markdown]
// 24.1 Code ทื่ต้องเพิ่ม
//
// >    ```cs
// >    buttonAdd.Location = new Point(59, 79);
// >    buttonAdd.Name = "buttonAdd";
// >    buttonAdd.Size = new Size(75, 23);
// >    buttonAdd.Text = "Add";
// >    Controls.Add(buttonAdd);
// >    ```
//
// 24.2 รันโปรแกรม โดยพิมพ์  `dotnet run` ใน terminal
//
// 24.3 สังเกตุและบันทึกผล

// %% [markdown]
// ![Screenshot 2024-12-20 150639.png](<attachment:Screenshot 2024-12-20 150639.png>)

// %% [markdown]
// #### 25 เพิ่ม Event ให้ปุ่ม buttonAdd

// %% [markdown]
// 25.1 ในไฟล์ Form1.Designer.cs ให้เพิ่มบรรทัดนี้ไว้ล่าง `Controls.Add(buttonAdd);`
//
// ```cs
// buttonAdd.Click += buttonAdd_Click;
// ```
//
//
// 25.2 ในไฟล์ Form1.cs  ให้เพิ่มเมธอด `buttonAdd_Click()` ไว้ใต้เมธอด `public Form1()`
//
// >    ```cs
// >    private void buttonAdd_Click(object sender, EventArgs e)
// >    {
// >        double a, b, c;
// >        double.TryParse(textBox_A.Text, out a);
// >        double.TryParse(textBox_B.Text, out b);
// >        c = a + b;
// >        textBox_C.Text = c.ToString();
// >    }
// >    ```
//
// 25.3 ฺ  พิมพ์คำสั่ง dotnet build ใน terminal ต้องไม่มี error ใดๆ ถ้ามีให้แก้ให้ถูกต้อง

// %% [markdown]
// #### 26 รันโปรแกรมและทดสอบการทำงาน
//
// 26.1 พิมพ์คำสั่ง dotnet run ใน terminal
//
// 26.2 ใส่ตัวเลขใน textbox A  และ B แล้วกดปุ่ม Add บันทึกผลที่ได้

// %% [markdown]
// ![Screenshot 2024-12-20 150807.png](<attachment:Screenshot 2024-12-20 150807.png>)

// %% [markdown]
// ## คำถาม
// 1. ถ้าไม่ใส่ตัวเลขใดๆ เลย ทั้งช่อง A และ B แล้วกด Add จะเกิดอะไรขึ้น
//
// = ที่ textBox C จะแสดงเลข 0
//
// 2. ถ้าใส่ตัวเลขใดเฉพาะช่อง A แต่ไม่ใส่ในช่อง B แล้วกด Add จะเกิดอะไรขึ้น
//
// = ที่ textBox C จะแสดงเลขเดียวกับที่กรอกใน textBox A
//
// 3. ถ้าใส่ตัวเลขใดเฉพาะช่อง B แต่ไม่ใส่ในช่อง A แล้วกด Add จะเกิดอะไรขึ้น
//
// = ที่ textBox C จะแสดงเลขเดียวกับที่กรอกใน textBox B
//
// 4. ถ้าใส่อักษรที่ไม่ใช่ตัวเลขลงในช่อง A หรือ B แล้วกด Add จะเกิดอะไรขึ้น
//
// = ที่ textBox จะแสดงเลข 0
//
// 5. ถ้าใส่เลขทศนิยมลงในช่อง A หรือ B แล้วกด Add จะเกิดอะไรขึ้น
//
// = สามารถคำนวณเลขทศนิยมได้ ที่ textBox C จะแสดงผลลัพธ์การคำนวณได้อย่างถูกต้อง
